# %% [markdown]
# ![SWISH.png](attachment:SWISH.png)

# %% [markdown]
# 1. (A web-based Prolog editor similar to Jupyter Notebook) https://cplint.ml.unife.it/example/prolog_tutorials.swinb

# %% [markdown]
# ***Reference:***
# [1] Rohner JC, Kjellerstrand H. Using logic programming for theory representation and scientific inference. New Ideas in Psychology. 2021 Apr 1;61:100838.
# [2] BUSCAROLI, Riccardo, et al. A Prolog application for reasoning on maths puzzles with diagrams. Journal of Experimental & Theoretical Artificial Intelligence, 2022, 1-21.
# [3] JULIÁN-IRANZO, Pascual; SÁENZ-PÉREZ, Fernando. Bousi∼ Prolog: Design and implementation of a proximity-based fuzzy logic programming language. Expert Systems with Applications, 2023, 213: 118858.
# [4] NÁPOLES, Gonzalo, et al. Prolog-based agnostic explanation module for structured pattern classification. Information Sciences, 2023, 622: 1196-1227.
# [5] Valdes, A. Prolog-Mazes. 2023 Oct 10. Available from: GitHub. https://github.com/Amable-Valdes/Prolog-Mazes
# [6] Dloreti. spatial-reasoning. Available from: GitHub. https://github.com/ai-unibo/spatial-reasoning
